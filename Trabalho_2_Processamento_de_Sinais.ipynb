# %% [markdown]
# <a href="https://colab.research.google.com/github/raphaelPinheiro26/Processamento-de-Sianis-e-Imagens-Biom-dicas/blob/main/Trabalho_2_Processamento_de_Sinais.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Processamento de Sinais e Imagens Biomédicas (Sistemas Biomédicos)
#
#
# Instruções:
#
#
#
# *   Leia com atenção toda a parte introdutória, pois fará diferença para esta e demais listas!
# *   Deve-se colocar comentários nos códigos desenvolvidos.
# *   As perguntas devem ser respondidas também como comentários no arquivo.
# *   Colocar seu nome e número da matricula abaixo.
# *   Quaisquer problemas na execução das listas, entrar em contato com o professor.
# *   Depois de terminados os exercícios, deve ser gerado um arquivo extensão .ipynb para ser enviado ao professor pelo TEAMS da disciplina até a data máxima de entrega.
# *   Caso não seja enviado - ou identifique-se cópia - o aluno ficará sem nota.
#
#
#
# ---

# %% [markdown]
# `Nome: `
#
# `Número FATEC: `
#
# `e-mail: `

# %% [markdown]
# ## PyPlot
#
# O pyplot é um submódulo do Matplotlib que fornece uma interface conveniente para criar e personalizar gráficos. Trata-se de uma coleção de funções que simplificam o processo de criação e modificação de gráficos, sem ter que se preocupar com os detalhes subjacentes da biblioteca Matplotlib.
#
# Ao importar matplotlib.pyplot, importamos esta coleção de funções, que inclui as funções:
#
# * plot(): Cria um gráfico de linha ou gráfico de dispersão.
# * hist(): Cria um histograma.
# * scatter(): Cria um gráfico de dispersão.
# * bar(): Cria um gráfico de barras.
# * pie(): Cria um gráfico de pizza.
# * xlabel(): define o rótulo para o eixo x.
# * ylabel(): define o rótulo para o eixo y.
# * title(): Define o título do gráfico.
# * legend(): Adiciona uma legenda ao gráfico.
# * xlim(): Define os limites para o eixo x.
# * ylim(): Define os limites para o eixo y.

# %%
# @title Default title text
InputSignal_1kHz_15kHz =[

+0.0000000000, +0.5924659585, -0.0947343455, +0.1913417162, +1.0000000000, +0.4174197128, +0.3535533906, +1.2552931065,
+0.8660254038, +0.4619397663, +1.3194792169, +1.1827865776, +0.5000000000, +1.1827865776, +1.3194792169, +0.4619397663,
+0.8660254038, +1.2552931065, +0.3535533906, +0.4174197128, +1.0000000000, +0.1913417162, -0.0947343455, +0.5924659585,
-0.0000000000, -0.5924659585, +0.0947343455, -0.1913417162, -1.0000000000, -0.4174197128, -0.3535533906, -1.2552931065,
-0.8660254038, -0.4619397663, -1.3194792169, -1.1827865776, -0.5000000000, -1.1827865776, -1.3194792169, -0.4619397663,
-0.8660254038, -1.2552931065, -0.3535533906, -0.4174197128, -1.0000000000, -0.1913417162, +0.0947343455, -0.5924659585,
+0.0000000000, +0.5924659585, -0.0947343455, +0.1913417162, +1.0000000000, +0.4174197128, +0.3535533906, +1.2552931065,
+0.8660254038, +0.4619397663, +1.3194792169, +1.1827865776, +0.5000000000, +1.1827865776, +1.3194792169, +0.4619397663,
+0.8660254038, +1.2552931065, +0.3535533906, +0.4174197128, +1.0000000000, +0.1913417162, -0.0947343455, +0.5924659585,
+0.0000000000, -0.5924659585, +0.0947343455, -0.1913417162, -1.0000000000, -0.4174197128, -0.3535533906, -1.2552931065,
-0.8660254038, -0.4619397663, -1.3194792169, -1.1827865776, -0.5000000000, -1.1827865776, -1.3194792169, -0.4619397663,
-0.8660254038, -1.2552931065, -0.3535533906, -0.4174197128, -1.0000000000, -0.1913417162, +0.0947343455, -0.5924659585,
+0.0000000000, +0.5924659585, -0.0947343455, +0.1913417162, +1.0000000000, +0.4174197128, +0.3535533906, +1.2552931065,
+0.8660254038, +0.4619397663, +1.3194792169, +1.1827865776, +0.5000000000, +1.1827865776, +1.3194792169, +0.4619397663,
+0.8660254038, +1.2552931065, +0.3535533906, +0.4174197128, +1.0000000000, +0.1913417162, -0.0947343455, +0.5924659585,
+0.0000000000, -0.5924659585, +0.0947343455, -0.1913417162, -1.0000000000, -0.4174197128, -0.3535533906, -1.2552931065,
-0.8660254038, -0.4619397663, -1.3194792169, -1.1827865776, -0.5000000000, -1.1827865776, -1.3194792169, -0.4619397663,
-0.8660254038, -1.2552931065, -0.3535533906, -0.4174197128, -1.0000000000, -0.1913417162, +0.0947343455, -0.5924659585,
-0.0000000000, +0.5924659585, -0.0947343455, +0.1913417162, +1.0000000000, +0.4174197128, +0.3535533906, +1.2552931065,
+0.8660254038, +0.4619397663, +1.3194792169, +1.1827865776, +0.5000000000, +1.1827865776, +1.3194792169, +0.4619397663,
+0.8660254038, +1.2552931065, +0.3535533906, +0.4174197128, +1.0000000000, +0.1913417162, -0.0947343455, +0.5924659585,
-0.0000000000, -0.5924659585, +0.0947343455, -0.1913417162, -1.0000000000, -0.4174197128, -0.3535533906, -1.2552931065,
-0.8660254038, -0.4619397663, -1.3194792169, -1.1827865776, -0.5000000000, -1.1827865776, -1.3194792169, -0.4619397663,
-0.8660254038, -1.2552931065, -0.3535533906, -0.4174197128, -1.0000000000, -0.1913417162, +0.0947343455, -0.5924659585,
+0.0000000000, +0.5924659585, -0.0947343455, +0.1913417162, +1.0000000000, +0.4174197128, +0.3535533906, +1.2552931065,
+0.8660254038, +0.4619397663, +1.3194792169, +1.1827865776, +0.5000000000, +1.1827865776, +1.3194792169, +0.4619397663,
+0.8660254038, +1.2552931065, +0.3535533906, +0.4174197128, +1.0000000000, +0.1913417162, -0.0947343455, +0.5924659585,
+0.0000000000, -0.5924659585, +0.0947343455, -0.1913417162, -1.0000000000, -0.4174197128, -0.3535533906, -1.2552931065,
-0.8660254038, -0.4619397663, -1.3194792169, -1.1827865776, -0.5000000000, -1.1827865776, -1.3194792169, -0.4619397663,
-0.8660254038, -1.2552931065, -0.3535533906, -0.4174197128, -1.0000000000, -0.1913417162, +0.0947343455, -0.5924659585,
-0.0000000000, +0.5924659585, -0.0947343455, +0.1913417162, +1.0000000000, +0.4174197128, +0.3535533906, +1.2552931065,
+0.8660254038, +0.4619397663, +1.3194792169, +1.1827865776, +0.5000000000, +1.1827865776, +1.3194792169, +0.4619397663,
+0.8660254038, +1.2552931065, +0.3535533906, +0.4174197128, +1.0000000000, +0.1913417162, -0.0947343455, +0.5924659585,
+0.0000000000, -0.5924659585, +0.0947343455, -0.1913417162, -1.0000000000, -0.4174197128, -0.3535533906, -1.2552931065,
-0.8660254038, -0.4619397663, -1.3194792169, -1.1827865776, -0.5000000000, -1.1827865776, -1.3194792169, -0.4619397663,
-0.8660254038, -1.2552931065, -0.3535533906, -0.4174197128, -1.0000000000, -0.1913417162, +0.0947343455, -0.5924659585,
-0.0000000000, +0.5924659585, -0.0947343455, +0.1913417162, +1.0000000000, +0.4174197128, +0.3535533906, +1.2552931065,
+0.8660254038, +0.4619397663, +1.3194792169, +1.1827865776, +0.5000000000, +1.1827865776, +1.3194792169, +0.4619397663,
+0.8660254038, +1.2552931065, +0.3535533906, +0.4174197128, +1.0000000000, +0.1913417162, -0.0947343455, +0.5924659585,
+0.0000000000, -0.5924659585, +0.0947343455, -0.1913417162, -1.0000000000, -0.4174197128, -0.3535533906, -1.2552931065,
]

# %%
#PyPlot Lib

from matplotlib import pyplot as plt #da biblioteca matplot , eu quero o pedaço pyplot e vou chamr como plt
from matplotlib import style

x = [1,2,3,4,5,6] #Variavel independente
y = [7,5,6,7,8,9] #valores plotados

x2 = [1,2,3,4,5,6] #Variavel independente
y2 = [3,6,5,7,8,6] #valores plotados

style.use('dark_background')
plt.plot(x,y, label = 'Linha 1')
plt.plot(x2,y2, label = 'Linha 2')
plt.xlabel(' Eixo X')
plt.ylabel('Eixo Y')
plt.title('Gráfico') #Titulo do gráfico

plt.legend()
plt.show()

# %%
# SubPlot

from matplotlib import pyplot as plt #da biblioteca matplot , eu quero o pedaço pyplot e vou chamr como plt
from matplotlib import style

style.use ('ggplot')
style.use('dark_background')

f,pltr_arr= plt.subplots(3,sharex=True)
f.suptitle("Subplot")


pltr_arr[0].plot(InputSignal_1kHz_15kHz, color='magenta')
pltr_arr[0].set_title('Subplot 1', color = 'magenta')

pltr_arr[1].plot(InputSignal_1kHz_15kHz, color='yellow')
pltr_arr[1].set_title('Subplot 2', color = 'yellow')

pltr_arr[2].plot(InputSignal_1kHz_15kHz, color ='red')
pltr_arr[2].set_title('Subplot 3', color = 'red')

plt.show()

# %%
# Gerando Sinais

from scipy import signal
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import style


#Amostragem do Sinal de 2.000Hz
t = np.linspace(0,1.0,2001) #valor mais baixo, valor mais alto, quantidade de elementos


sig_5Hz = np.sin(2*np.pi*5*t) #2*pi*5frequencia
sig_25Hz = np.sin(2*np.pi*25*t)

combi = sig_5Hz + sig_25Hz

#plot o gráfico desses dois sinais
style.use ('ggplot')
style.use('dark_background')

f,pltr_arr= plt.subplots(3,sharex=True)
f.suptitle("Subplot")


pltr_arr[0].plot(sig_5Hz, color='magenta')
pltr_arr[0].set_title(' 5 Hz', color = 'magenta')

pltr_arr[1].plot(sig_25Hz, color='yellow')
pltr_arr[1].set_title('25 Hz', color = 'yellow')

pltr_arr[2].plot(combi, color ='red')
pltr_arr[2].set_title('Combinando sinais', color = 'red')

plt.show()

# %% [markdown]
# # Estatística - Medidas de Dispersão
#
# ## Média
#
# * Média do Sinal
# * Soma os valores da amostra e divide pelo total de amostras
# * Mu
# * Valor DC do sinal
#
# ![image.png](data:image/png;base64,...)
#
#
# ## Desvio Padrão
# - Desvio Padrão mostra o quanto longe o sinal está da média
# - O poder desta flutuação é chamado de variância
# - Sigma
#
# ![image.png](data:image/png;base64,...)
#
#
# ## Variância
#  - Quadrado do desvio padrão
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ## Largura de Meia Altura (FWHM)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)

# %%
#Media, Desvio Padrão e Variância

from matplotlib import pyplot as plt
import numpy as np


media_sinal = np.mean(InputSignal_1kHz_15kHz)
print("A média é :", media_sinal)

desvio = np.std(InputSignal_1kHz_15kHz)
print("O desvio é :", desvio)

variancia = np.var(InputSignal_1kHz_15kHz)
print("A variancia é :", variancia)
# Out:
# A média é : 0.0371118795884375
# O desvio é : 0.7862706055516132
# A variancia é : 0.6182214651545005

# %% [markdown]
# # Exerecicio 1
#
# Descreva plote os gráficos a seguir e Comente os resultados:

# %%
#Escreva seu código aqui
#1 - Seno  ... sendo A = 4, B= 36, C =6 e D=-4.
#2 - Cosseno  ... sendo A = -3, B= 0.33333...., C = 60 e D= 12.
#3 - exponecial A.e^(x.B +C) + D ...  Sendo A= 0,23 B= 5, C= 10, D = 2
#4 - Log  A.log(x+B)+C ... Sendo A = 2,45 B=10 e C -2

# %% [markdown]
# ##Exercício 1.1
# Faç a variação dos parametros A,B,C e D do exercício anterior e comente os resultados
# Dica: utilize um "slide bar" para fazer a variação

# %%
#Escreva seu código aqui

# %% [markdown]
# #Exercício 2
#
# Escolha uma das funções do exercício anterior e faça as seguintes Transformações plotando seus gráficos em subplot
#
# * Aumente o Ganho em 10x
# * Some por 5
# * Subtraia por pi
# * Faça um Shift de 3 posições

# %%
#Seu Código começa Aqui

# %% [markdown]
# #Exercicio 3
# Combine as seguintes funções do exercicio 1:
# - 1 e 3
# - 2 e 4
#
# Tire a média, o desvio padrão e a variância. Comente os resultados

# %%
#Seu Código começa Aqui

# %% [markdown]
# #Exercicio 4
# Com os sinais combinados do exercício anterior, aplique o filtro da média com kernel de 3 pontos, e verifique novamente a média, desvio padrão e variância. Comente os resultados.

# %%
#Seu Código começa Aqui
